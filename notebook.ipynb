# %%
from genetics import Genetics
import pandas as pd

pd.options.display.max_columns=100

# %%
api = Genetics()

# %%
variants = ['1_67205085_T_C', '16_50691282_C_T', '3_36814539_T_C']

res = api.genes_for_variant(variants)
res.sort_values('overallScore', ascending=False).head(10)
# Out:
#             variant  overallScore  \
# 21  16_50691282_C_T      0.271978
# 9    1_67205085_T_C      0.254121
# 36  16_50691282_C_T      0.253846
# 20  16_50691282_C_T      0.235714
# 33  16_50691282_C_T      0.226648
# 35  16_50691282_C_T      0.208516
# 44   3_36814539_T_C      0.190385
# 6    1_67205085_T_C      0.172527
# 46   3_36814539_T_C      0.145055
# 43   3_36814539_T_C      0.135989
#
#                                                  qtls  \
# 21  [{'typeId': 'eqtl', 'sourceId': 'eqtl', 'aggre...
# 9   [{'typeId': 'eqtl', 'sourceId': 'eqtl', 'aggre...
# 36  [{'typeId': 'eqtl', 'sourceId': 'eqtl', 'aggre...
# 20  [{'typeId': 'eqtl', 'sourceId': 'eqtl', 'aggre...
# 33  [{'typeId': 'eqtl', 'sourceId': 'eqtl', 'aggre...
# 35  [{'typeId': 'eqtl', 'sourceId': 'eqtl', 'aggre...
# 44  [{'typeId': 'eqtl', 'sourceId': 'eqtl', 'aggre...
# 6   [{'typeId': 'eqtl', 'sourceId': 'eqtl', 'aggre...
# 46  [{'typeId': 'eqtl', 'sourceId': 'eqtl', 'aggre...
# 43  [{'typeId': 'eqtl', 'sourceId': 'eqtl', 'aggre...
#
#                                             intervals  \
# 21                                                 []
# 9                                                  []
# 36                                                 []
# 20                                                 []
# 33                                                 []
# 35                                                 []
# 44                                                 []
# 6                                                  []
# 46                                                 []
# 43  [{'typeId': 'pchic', 'sourceId': 'jung2019', '...
#
#                                 functionalPredictions  \
# 21                                                 []
# 9   [{'typeId': 'fpred', 'sourceId': 'vep', 'aggre...
# 36                                                 []
# 20                                                 []
# 33                                                 []
# 35                                                 []
# 44                                                 []
# 6   [{'typeId': 'fpred', 'sourceId': 'vep', 'aggre...
# 46                                                 []
# 43                                                 []
#
#                                             distances          gene_id  \
# 21  [{'typeId': 'distance', 'sourceId': 'canonical...  ENSG00000167207
# 9   [{'typeId': 'distance', 'sourceId': 'canonical...  ENSG00000162594
# 36  [{'typeId': 'distance', 'sourceId': 'canonical...  ENSG00000270120
# 20  [{'typeId': 'distance', 'sourceId': 'canonical...  ENSG00000167208
# 33  [{'typeId': 'distance', 'sourceId': 'canonical...  ENSG00000261644
# 35  [{'typeId': 'distance', 'sourceId': 'canonical...  ENSG00000083799
# 44  [{'typeId': 'distance', 'sourceId': 'canonical...  ENSG00000093167
# 6   [{'typeId': 'distance', 'sourceId': 'canonical...  ENSG00000203963
# 46  [{'typeId': 'distance', 'sourceId': 'canonical...  ENSG00000168016
# 43  [{'typeId': 'distance', 'sourceId': 'canonical...  ENSG00000163673
#
#    gene_symbol                                   gene_description  \
# 21        NOD2  nucleotide binding oligomerization domain cont...
# 9        IL23R  interleukin 23 receptor [Source:HGNC Symbol;Ac...
# 36  AC007728.3                                   novel transcript
# 20       SNX20  sorting nexin 20 [Source:HGNC Symbol;Acc:HGNC:...
# 33  AC007728.2       novel transcript, antisense to CYLD and NOD2
# 35        CYLD  CYLD lysine 63 deubiquitinase [Source:HGNC Sym...
# 44     LRRFIP2  LRR binding FLII interacting protein 2 [Source...
# 6     C1orf141  chromosome 1 open reading frame 141 [Source:HG...
# 46      TRANK1  tetratricopeptide repeat and ankyrin repeat co...
# 43       DCLK3  doublecortin like kinase 3 [Source:HGNC Symbol...
#
#    gene_chromosome  gene_start  gene_end  gene_tss    gene_bioType  \
# 21              16    50693588  50734041  50693588  protein_coding
# 9                1    67138907  67259979  67138907  protein_coding
# 36              16    50712844  50713589  50712844  sense_intronic
# 20              16    50666300  50681353  50681353  protein_coding
# 33              16    50727417  50742815  50742815       antisense
# 35              16    50742050  50801935  50742050  protein_coding
# 44               3    37052626  37183689  37183689  protein_coding
# 6                1    67092165  67231853  67231853  protein_coding
# 46               3    36826820  36945098  36945098  protein_coding
# 43               3    36712422  36764349  36764349  protein_coding
#
#     gene_fwdStrand                                         gene_exons
# 21            True  [50731747, 50733077, 50729818, 50729901, 50725...
# 9             True  [67219574, 67219730, 67206910, 67207055, 67200...
# 36            True                               [50712844, 50713589]
# 20           False  [50671629, 50674074, 50675770, 50675921, 50677...
# 33           False  [50729843, 50729953, 50732218, 50732360, 50740...
# 35            True  [50775166, 50775174, 50754319, 50754424, 50751...
# 44           False  [37066224, 37066325, 37072790, 37072882, 37075...
# 6            False  [67127166, 67127257, 67131142, 67131227, 67231...
# 46           False  [36864319, 36864480, 36847200, 36847346, 36851...
# 43           False  [36718010, 36718177, 36721527, 36721659, 36737...

# %%
man = api.study_info(study_ids=['GCST003184', 'GCST005527'])
man
# Out:
#       studyId                          traitReported      traitEfos  \
# 0  GCST003184  Atopic dermatitis [EA, fixed effects]  [EFO_0000274]
# 1  GCST005527                              Psoriasis  [EFO_0000676]
#
#             pmid     pubDate pubJournal  \
# 0  PMID:26482879  2015-10-19  Nat Genet
# 1  PMID:23143594  2012-12-01  Nat Genet
#
#                                             pubTitle      pubAuthor  \
# 0  Multi-ancestry genome-wide association study o...  Paternoster L
# 1  Identification of 15 new psoriasis susceptibil...        Tsoi LC
#
#    hasSumsStats                                    ancestryInitial  \
# 0         False  [Hispanic or Latin American=1892, African Amer...
# 1          True                                   [European=33394]
#
#                                  ancestryReplication  nInitial  nReplication  \
# 0  [European=257125, African American or Afro-Car...    116863      260787.0
# 1                                                 []     33394           NaN
#
#    nCases  nTotal  traitCategory  numAssocLoci
# 0   21399  377650  Immune system            24
# 1   10588   33394  Immune system            89

# %%
man = api.manhattan(study_ids=['GCST003184'])
man.sort_values('pval').head(10)
# Out:
#                                             bestGenes bestColocGenes  \
# 13  [{'gene': {'id': 'ENSG00000172818', 'symbol': ...             []
# 16  [{'gene': {'id': 'ENSG00000272575', 'symbol': ...             []
# 12  [{'gene': {'id': 'ENSG00000172818', 'symbol': ...             []
# 7   [{'gene': {'id': 'ENSG00000197375', 'symbol': ...             []
# 10  [{'gene': {'id': 'ENSG00000205189', 'symbol': ...             []
# 17  [{'gene': {'id': 'ENSG00000092020', 'symbol': ...             []
# 6   [{'gene': {'id': 'ENSG00000168685', 'symbol': ...             []
# 5   [{'gene': {'id': 'ENSG00000115604', 'symbol': ...             []
# 14  [{'gene': {'id': 'ENSG00000137507', 'symbol': ...             []
# 21  [{'gene': {'id': 'ENSG00000258366', 'symbol': ...             []
#
#                                       bestLocus2Genes          pval  \
# 13  [{'gene': {'id': 'ENSG00000172818', 'symbol': ...  2.000000e-19
# 16                                                 []  2.000000e-18
# 12  [{'gene': {'id': 'ENSG00000172818', 'symbol': ...  2.000000e-18
# 7                                                  []  4.000000e-17
# 10  [{'gene': {'id': 'ENSG00000205189', 'symbol': ...  2.000000e-16
# 17                                                 []  2.000000e-15
# 6   [{'gene': {'id': 'ENSG00000168685', 'symbol': ...  3.000000e-14
# 5   [{'gene': {'id': 'ENSG00000115607', 'symbol': ...  2.000000e-13
# 14                                                 []  5.000000e-13
# 21  [{'gene': {'id': 'ENSG00000026036', 'symbol': ...  7.000000e-13
#
#     pvalMantissa  pvalExponent oddsRatio oddsRatioCILower oddsRatioCIUpper  \
# 13             2           -19      1.12          1.09274          1.14794
# 16             2           -18      0.94         0.927072         0.953108
# 12             2           -18      None             None             None
# 7              4           -17      1.14          1.10573          1.17534
# 10             2           -16      0.94         0.926237         0.953968
# 17             2           -15      1.08          1.05968          1.10071
# 6              3           -14      0.94         0.925116         0.955124
# 5              2           -13  0.900901         0.876171         0.926329
# 14             5           -13      1.09          1.06481          1.11578
# 21             7           -13   1.11111          1.07961          1.14353
#
#     beta betaCILower betaCIUpper direction credibleSetSize  ldSetSize  \
# 13  None        None        None         +            None          2
# 16  None        None        None         -            None          1
# 12  None        None        None      None            None         35
# 7   None        None        None         +            None        107
# 10  None        None        None         -            None         94
# 17  None        None        None         +            None        237
# 6   None        None        None         -            None         42
# 5   None        None        None         -            None        158
# 14  None        None        None         +            None         19
# 21  None        None        None         +            None         91
#
#     totalSetSize        variant_id     variant_idB37 variant_rsId  \
# 13             2   11_65791795_A_G   11_65559266_A_G   rs10791824
# 16             1  11_128317488_T_C  11_128187383_T_C    rs7127307
# 12            35   11_65784486_A_G   11_65551957_A_G     rs479844
# 7            107   5_132655393_T_C   5_131991085_T_C   rs12188917
# 10            94    8_80373657_C_A    8_81285892_C_A    rs6473227
# 17           237   14_35103151_C_T   14_35572357_C_T    rs2143950
# 6             42    5_35883632_T_C    5_35883734_T_C   rs10214237
# 5            158   2_102410643_T_C   2_103027103_T_C    rs6419573
# 14            19   11_76570549_C_T   11_76281593_C_T    rs2212434
# 21            91   20_63671762_C_A   20_62303115_C_A    rs4809219
#
#    variant_chromosome  variant_position variant_chromosomeB37  \
# 13                 11          65791795                    11
# 16                 11         128317488                    11
# 12                 11          65784486                    11
# 7                   5         132655393                     5
# 10                  8          80373657                     8
# 17                 14          35103151                    14
# 6                   5          35883632                     5
# 5                   2         102410643                     2
# 14                 11          76570549                    11
# 21                 20          63671762                    20
#
#     variant_positionB37 variant_refAllele variant_altAllele  \
# 13             65559266                 A                 G
# 16            128187383                 T                 C
# 12             65551957                 A                 G
# 7             131991085                 T                 C
# 10             81285892                 C                 A
# 17             35572357                 C                 T
# 6              35883734                 T                 C
# 5             103027103                 T                 C
# 14             76281593                 C                 T
# 21             62303115                 C                 A
#
#    variant_nearestGene_id variant_nearestGene_symbol  \
# 13        ENSG00000255120                  OVOL1-AS1
# 16        ENSG00000272575                  LINC02098
# 12        ENSG00000172818                      OVOL1
# 7         ENSG00000169194                       IL13
# 10        ENSG00000253238                 AC034114.2
# 17        ENSG00000100890                   KIAA0391
# 6         ENSG00000168685                       IL7R
# 5         ENSG00000115607                    IL18RAP
# 14        ENSG00000255479                 AP001189.6
# 21        ENSG00000026036             RTEL1-TNFRSF6B
#
#                       variant_nearestGene_description  \
# 13  OVOL1 antisense RNA 1 [Source:HGNC Symbol;Acc:...
# 16  long intergenic non-protein coding RNA 2098 [S...
# 12  ovo like transcriptional repressor 1 [Source:H...
# 7   interleukin 13 [Source:HGNC Symbol;Acc:HGNC:5973]
# 10                                   novel transcript
# 17       KIAA0391 [Source:HGNC Symbol;Acc:HGNC:19958]
# 6   interleukin 7 receptor [Source:HGNC Symbol;Acc...
# 5   interleukin 18 receptor accessory protein [Sou...
# 14                                   novel transcript
# 21  RTEL1-TNFRSF6B readthrough (NMD candidate) [So...
#
#    variant_nearestGene_chromosome  variant_nearestGene_start  \
# 13                             11                   65789051
# 16                             11                  128208749
# 12                             11                   65787063
# 7                               5                  132656263
# 10                              8                   80265927
# 17                             14                   35121846
# 6                               5                   35852695
# 5                               2                  102418689
# 14                             11                   76625462
# 21                             20                   63659300
#
#     variant_nearestGene_end  variant_nearestGene_tss  \
# 13                 65790868                 65790868
# 16                128241441                128208749
# 12                 65797214                 65787063
# 7                 132661110                132656263
# 10                 80484316                 80265927
# 17                 35277614                 35121846
# 6                  35879603                 35852695
# 5                 102452565                102418689
# 14                 76626834                 76626834
# 21                 63698684                 63659300
#
#    variant_nearestGene_bioType  variant_nearestGene_fwdStrand  \
# 13                   antisense                          False
# 16                     lincRNA                           True
# 12              protein_coding                           True
# 7               protein_coding                           True
# 10                     lincRNA                           True
# 17              protein_coding                           True
# 6               protein_coding                           True
# 5               protein_coding                           True
# 14                     lincRNA                          False
# 21              protein_coding                           True
#
#                             variant_nearestGene_exons  \
# 13           [65789051, 65789437, 65790762, 65790868]
# 16  [128213982, 128214096, 128211387, 128211719, 1...
# 12  [65795046, 65797214, 65794538, 65794727, 65794...
# 7   [132660175, 132661110, 132659724, 132659828, 1...
# 10  [80483580, 80484316, 80482608, 80482715, 80448...
# 17  [35273435, 35274065, 35270401, 35270596, 35266...
# 6   [35875983, 35879603, 35875512, 35875587, 35874...
# 5   [102423178, 102423347, 102451766, 102452565, 1...
# 14           [76625462, 76626030, 76626573, 76626834]
# 21  [63688139, 63688179, 63689502, 63689648, 63659...
#
#     variant_nearestGeneDistance variant_nearestCodingGene_id  \
# 13                          927              ENSG00000172818
# 16                       108739              ENSG00000134954
# 12                         2577              ENSG00000172818
# 7                           870              ENSG00000169194
# 10                       107730              ENSG00000205189
# 17                        18695              ENSG00000100890
# 6                         30937              ENSG00000168685
# 5                          8046              ENSG00000115607
# 14                        56285              ENSG00000137507
# 21                        12462              ENSG00000026036
#
#    variant_nearestCodingGene_symbol  \
# 13                            OVOL1
# 16                             ETS1
# 12                            OVOL1
# 7                              IL13
# 10                           ZBTB10
# 17                         KIAA0391
# 6                              IL7R
# 5                           IL18RAP
# 14                           LRRC32
# 21                   RTEL1-TNFRSF6B
#
#                 variant_nearestCodingGene_description  \
# 13  ovo like transcriptional repressor 1 [Source:H...
# 16  ETS proto-oncogene 1, transcription factor [So...
# 12  ovo like transcriptional repressor 1 [Source:H...
# 7   interleukin 13 [Source:HGNC Symbol;Acc:HGNC:5973]
# 10  zinc finger and BTB domain containing 10 [Sour...
# 17       KIAA0391 [Source:HGNC Symbol;Acc:HGNC:19958]
# 6   interleukin 7 receptor [Source:HGNC Symbol;Acc...
# 5   interleukin 18 receptor accessory protein [Sou...
# 14  leucine rich repeat containing 32 [Source:HGNC...
# 21  RTEL1-TNFRSF6B readthrough (NMD candidate) [So...
#
#    variant_nearestCodingGene_chromosome  variant_nearestCodingGene_start  \
# 13                                   11                         65787063
# 16                                   11                        128458761
# 12                                   11                         65787063
# 7                                     5                        132656263
# 10                                    8                         80485619
# 17                                   14                         35121846
# 6                                     5                         35852695
# 5                                     2                        102418689
# 14                                   11                         76657524
# 21                                   20                         63659300
#
#     variant_nearestCodingGene_end  variant_nearestCodingGene_tss  \
# 13                       65797214                       65787063
# 16                      128587558                      128587558
# 12                       65797214                       65787063
# 7                       132661110                      132656263
# 10                       80526265                       80485619
# 17                       35277614                       35121846
# 6                        35879603                       35852695
# 5                       102452565                      102418689
# 14                       76670747                       76670747
# 21                       63698684                       63659300
#
#    variant_nearestCodingGene_bioType  variant_nearestCodingGene_fwdStrand  \
# 13                    protein_coding                                 True
# 16                    protein_coding                                False
# 12                    protein_coding                                 True
# 7                     protein_coding                                 True
# 10                    protein_coding                                 True
# 17                    protein_coding                                 True
# 6                     protein_coding                                 True
# 5                     protein_coding                                 True
# 14                    protein_coding                                False
# 21                    protein_coding                                 True
#
#                       variant_nearestCodingGene_exons  \
# 13  [65795046, 65797214, 65794538, 65794727, 65794...
# 16  [128480191, 128480451, 128484823, 128485071, 1...
# 12  [65795046, 65797214, 65794538, 65794727, 65794...
# 7   [132660175, 132661110, 132659724, 132659828, 1...
# 10  [80518782, 80518954, 80518403, 80518579, 80513...
# 17  [35273435, 35274065, 35270401, 35270596, 35266...
# 6   [35875983, 35879603, 35875512, 35875587, 35874...
# 5   [102423178, 102423347, 102451766, 102452565, 1...
# 14  [76665871, 76665958, 76669762, 76670000, 76657...
# 21  [63688139, 63688179, 63689502, 63689648, 63659...
#
#     variant_nearestCodingGeneDistance variant_mostSevereConsequence  \
# 13                               4732                intron_variant
# 16                             270070            intergenic_variant
# 12                               2577         upstream_gene_variant
# 7                                 870                intron_variant
# 10                             111962            intergenic_variant
# 17                              18695                intron_variant
# 6                               30937       downstream_gene_variant
# 5                                8046         upstream_gene_variant
# 14                             100198            intergenic_variant
# 21                              12462                intron_variant
#
#     variant_caddRaw  variant_caddPhred  variant_gnomadAFR  variant_gnomadAMR  \
# 13         0.515988              9.530           0.427273           0.372038
# 16        -0.263726              0.466           0.392364           0.476359
# 12         0.049623              3.422           0.220037           0.334123
# 7          0.042340              3.301           0.423784           0.238038
# 10        -0.192932              0.749           0.370849           0.542755
# 17         0.431774              8.720           0.146044           0.187500
# 6         -0.073157              1.671           0.100115           0.188679
# 5          0.015605              2.865           0.897005           0.494090
# 14         0.009860              2.775           0.274194           0.365248
# 21        -0.136724              1.094           0.942036           0.823113
#
#     variant_gnomadASJ  variant_gnomadEAS  variant_gnomadFIN  \
# 13           0.593103           0.487773           0.637413
# 16           0.444828           0.622108           0.576037
# 12           0.562500           0.266055           0.595266
# 7            0.244755           0.158269           0.251911
# 10           0.583333           0.428202           0.660953
# 17           0.241379           0.358065           0.178756
# 6            0.265517           0.141849           0.337370
# 5            0.770833           0.537967           0.814516
# 14           0.506944           0.466365           0.404145
# 21           0.784722           0.295664           0.794804
#
#     variant_gnomadNFE  variant_gnomadNFEEST  variant_gnomadNFENWE  \
# 13           0.591625              0.635627              0.571646
# 16           0.491739              0.543107              0.469312
# 12           0.571541              0.602117              0.558017
# 7            0.238233              0.299910              0.206013
# 10           0.623129              0.635389              0.616932
# 17           0.163335              0.156918              0.165463
# 6            0.269281              0.280909              0.266838
# 5            0.768108              0.747255              0.778855
# 14           0.444069              0.418848              0.451481
# 21           0.783652              0.817007              0.768293
#
#     variant_gnomadNFESEU  variant_gnomadNFEONF  variant_gnomadOTH       study
# 13              0.537736              0.580282           0.599448  GCST003184
# 16              0.490566              0.471805           0.531423  GCST003184
# 12              0.528302              0.562736           0.540816  GCST003184
# 7               0.259615              0.237983           0.250000  GCST003184
# 10              0.641509              0.620787           0.606481  GCST003184
# 17              0.179245              0.167760           0.189687  GCST003184
# 6               0.301887              0.252572           0.276243  GCST003184
# 5               0.783019              0.768762           0.771140  GCST003184
# 14              0.518868              0.464789           0.406308  GCST003184
# 21              0.735849              0.778457           0.811338  GCST003184

# %%
res = api.tag_variants_and_studies_for_index_variant(index_variants=['11_65791795_A_G'], study_id='GCST003184')
res
# Out:
#             pval  pvalMantissa  pvalExponent  nTotal  nCases overallR2  \
# 10  2.000000e-19           2.0           -19  377650   21399  0.913806
# 15  2.000000e-19           2.0           -19  377650   21399         1
#
#    afr1000GProp amr1000GProp eas1000GProp eur1000GProp sas1000GProp log10Abf  \
# 10     0.146286     0.108368     0.676557    0.0687897            0     None
# 15     0.146286     0.108368     0.676557    0.0687897            0     None
#
#    posteriorProbability oddsRatio oddsRatioCILower oddsRatioCIUpper  beta  \
# 10                 None      1.12          1.09274          1.14794  None
# 15                 None      1.12          1.09274          1.14794  None
#
#    betaCILower betaCIUpper direction study_studyId    tagVariant_id  \
# 10        None        None         +    GCST003184  11_65788053_A_G
# 15        None        None         +    GCST003184  11_65791795_A_G
#
#    tagVariant_idB37 tagVariant_rsId tagVariant_chromosome  \
# 10  11_65555524_A_G      rs10896045                    11
# 15  11_65559266_A_G      rs10791824                    11
#
#     tagVariant_position tagVariant_chromosomeB37  tagVariant_positionB37  \
# 10             65788053                       11                65555524
# 15             65791795                       11                65559266
#
#    tagVariant_refAllele tagVariant_altAllele tagVariant_nearestGene_id  \
# 10                    A                    G           ENSG00000172818
# 15                    A                    G           ENSG00000255120
#
#    tagVariant_nearestGene_symbol  \
# 10                         OVOL1
# 15                     OVOL1-AS1
#
#                    tagVariant_nearestGene_description  \
# 10  ovo like transcriptional repressor 1 [Source:H...
# 15  OVOL1 antisense RNA 1 [Source:HGNC Symbol;Acc:...
#
#    tagVariant_nearestGene_chromosome  tagVariant_nearestGene_start  \
# 10                                11                      65787063
# 15                                11                      65789051
#
#     tagVariant_nearestGene_end  tagVariant_nearestGene_tss  \
# 10                    65797214                    65787063
# 15                    65790868                    65790868
#
#    tagVariant_nearestGene_bioType  tagVariant_nearestGene_fwdStrand  \
# 10                 protein_coding                              True
# 15                      antisense                             False
#
#                          tagVariant_nearestGene_exons  \
# 10  [65795046, 65797214, 65794538, 65794727, 65794...
# 15           [65789051, 65789437, 65790762, 65790868]
#
#     tagVariant_nearestGeneDistance tagVariant_nearestCodingGene_id  \
# 10                             990                 ENSG00000172818
# 15                             927                 ENSG00000172818
#
#    tagVariant_nearestCodingGene_symbol  \
# 10                               OVOL1
# 15                               OVOL1
#
#              tagVariant_nearestCodingGene_description  \
# 10  ovo like transcriptional repressor 1 [Source:H...
# 15  ovo like transcriptional repressor 1 [Source:H...
#
#    tagVariant_nearestCodingGene_chromosome  \
# 10                                      11
# 15                                      11
#
#     tagVariant_nearestCodingGene_start  tagVariant_nearestCodingGene_end  \
# 10                            65787063                          65797214
# 15                            65787063                          65797214
#
#     tagVariant_nearestCodingGene_tss tagVariant_nearestCodingGene_bioType  \
# 10                          65787063                       protein_coding
# 15                          65787063                       protein_coding
#
#     tagVariant_nearestCodingGene_fwdStrand  \
# 10                                    True
# 15                                    True
#
#                    tagVariant_nearestCodingGene_exons  \
# 10  [65795046, 65797214, 65794538, 65794727, 65794...
# 15  [65795046, 65797214, 65794538, 65794727, 65794...
#
#     tagVariant_nearestCodingGeneDistance tagVariant_mostSevereConsequence  \
# 10                                   990                   intron_variant
# 15                                  4732                   intron_variant
#
#     tagVariant_caddRaw  tagVariant_caddPhred  tagVariant_gnomadAFR  \
# 10            0.498386                 9.368              0.464104
# 15            0.515988                 9.530              0.427273
#
#     tagVariant_gnomadAMR  tagVariant_gnomadASJ  tagVariant_gnomadEAS  \
# 10              0.438679              0.682759              0.485825
# 15              0.372038              0.593103              0.487773
#
#     tagVariant_gnomadFIN  tagVariant_gnomadNFE  tagVariant_gnomadNFEEST  \
# 10              0.714245              0.704406                 0.722934
# 15              0.637413              0.591625                 0.635627
#
#     tagVariant_gnomadNFENWE  tagVariant_gnomadNFESEU  tagVariant_gnomadNFEONF  \
# 10                 0.697715                 0.669811                 0.693715
# 15                 0.571646                 0.537736                 0.580282
#
#     tagVariant_gnomadOTH     queryVariant
# 10              0.690388  11_65791795_A_G
# 15              0.599448  11_65791795_A_G

# %%
res = api.index_variants_and_studies_for_tag_variant(index_variants=['11_65788053_A_G'], study_id='GCST003184')
res.head(10)
# Out:
#             pval  pvalMantissa  pvalExponent  nTotal  nCases  overallR2  \
# 12  2.000000e-19           2.0           -19  377650   21399   0.913806
#
#     afr1000GProp  amr1000GProp  eas1000GProp  eur1000GProp  sas1000GProp  \
# 12      0.146286      0.108368      0.676557       0.06879             0
#
#    log10Abf posteriorProbability oddsRatio oddsRatioCILower oddsRatioCIUpper  \
# 12     None                 None      1.12          1.09274          1.14794
#
#     beta betaCILower betaCIUpper direction study_studyId  indexVariant_id  \
# 12  None        None        None         +    GCST003184  11_65791795_A_G
#
#    indexVariant_idB37 indexVariant_rsId indexVariant_chromosome  \
# 12    11_65559266_A_G        rs10791824                      11
#
#     indexVariant_position indexVariant_chromosomeB37  \
# 12               65791795                         11
#
#     indexVariant_positionB37 indexVariant_refAllele indexVariant_altAllele  \
# 12                  65559266                      A                      G
#
#    indexVariant_nearestGene_id indexVariant_nearestGene_symbol  \
# 12             ENSG00000255120                       OVOL1-AS1
#
#                  indexVariant_nearestGene_description  \
# 12  OVOL1 antisense RNA 1 [Source:HGNC Symbol;Acc:...
#
#    indexVariant_nearestGene_chromosome  indexVariant_nearestGene_start  \
# 12                                  11                        65789051
#
#     indexVariant_nearestGene_end  indexVariant_nearestGene_tss  \
# 12                      65790868                      65790868
#
#    indexVariant_nearestGene_bioType  indexVariant_nearestGene_fwdStrand  \
# 12                        antisense                               False
#
#               indexVariant_nearestGene_exons  \
# 12  [65789051, 65789437, 65790762, 65790868]
#
#     indexVariant_nearestGeneDistance indexVariant_nearestCodingGene_id  \
# 12                               927                   ENSG00000172818
#
#    indexVariant_nearestCodingGene_symbol  \
# 12                                 OVOL1
#
#            indexVariant_nearestCodingGene_description  \
# 12  ovo like transcriptional repressor 1 [Source:H...
#
#    indexVariant_nearestCodingGene_chromosome  \
# 12                                        11
#
#     indexVariant_nearestCodingGene_start  indexVariant_nearestCodingGene_end  \
# 12                              65787063                            65797214
#
#     indexVariant_nearestCodingGene_tss indexVariant_nearestCodingGene_bioType  \
# 12                            65787063                         protein_coding
#
#     indexVariant_nearestCodingGene_fwdStrand  \
# 12                                      True
#
#                  indexVariant_nearestCodingGene_exons  \
# 12  [65795046, 65797214, 65794538, 65794727, 65794...
#
#     indexVariant_nearestCodingGeneDistance indexVariant_mostSevereConsequence  \
# 12                                    4732                     intron_variant
#
#     indexVariant_caddRaw  indexVariant_caddPhred  indexVariant_gnomadAFR  \
# 12              0.515988                    9.53                0.427273
#
#     indexVariant_gnomadAMR  indexVariant_gnomadASJ  indexVariant_gnomadEAS  \
# 12                0.372038                0.593103                0.487773
#
#     indexVariant_gnomadFIN  indexVariant_gnomadNFE  indexVariant_gnomadNFEEST  \
# 12                0.637413                0.591625                   0.635627
#
#     indexVariant_gnomadNFENWE  indexVariant_gnomadNFESEU  \
# 12                   0.571646                   0.537736
#
#     indexVariant_gnomadNFEONF  indexVariant_gnomadOTH     queryVariant
# 12                   0.580282                0.599448  11_65788053_A_G
